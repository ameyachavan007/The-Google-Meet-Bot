# %%
# !pip install selenium

# %%
# !pip install keyboard
# !pip install "python_telegram_bot==12.4.2"

# %%
# !pip install telegram

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import datetime
import time
import os
import re
import keyboard
import requests
from telegram import *
from telegram import ChatAction
from telegram.ext import *
import logging
from telegram.ext import Updater, CommandHandler, MessageHandler, Filters, CallbackQueryHandler, CallbackContext, run_async
from telegram import InlineKeyboardButton, InlineKeyboardMarkup, Update


logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')
# input our telegram bot unique api token
TOKEN = '1841656712:AAEyMPVPX2YWrvn73WOspK-5CSqubJBtjIw'

def start(update, context):
    logging.info("Starting stuff...")
    context.bot.send_message(chat_id= -587495317, text="Hi Miss Bhavika I'm here to replace bro(hugra) bot....don't worry I was created by copying the same code you wrote earlier...")

def login(update, context)

def sum(update, context):
    userId = -587495317
    context.bot.send_chat_action(chat_id=userId, action =ChatAction.TYPING)
    context.bot.send_message(chat_id=userId, text="Here is your answer: " + str(int(context.args[0])+int(context.args[1])))
    
def login(context):
    userId = -587495317
    
  
    
    
def error(update, context):
    logger.warning('Update "%s" caused error "%s"', update, context.error)
# to start the bot
def main():
    
    updater = Updater(TOKEN, use_context=True)

    dp = updater.dispatcher

    dp.add_handler(CommandHandler("start", start))
    dp.add_handler(CommandHandler("sum", sum))

    dp.add_error_handler(error)

    updater.start_polling()

    updater.idle()
if __name__ == '__main__':
    main()
# Out:
# 2021-07-05 20:26:37,080 - telegram.ext.dispatcher - DEBUG - Setting singleton dispatcher as None
# 2021-07-05 20:26:37,082 - telegram.bot - DEBUG - Entering: get_me
# 2021-07-05 20:26:37,084 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.telegram.org
# 2021-07-05 20:26:37,628 - telegram.vendor.ptb_urllib3.urllib3.connectionpool - DEBUG - https://api.telegram.org:443 "GET /bot1841656712:AAEyMPVPX2YWrvn73WOspK-5CSqubJBtjIw/getMe HTTP/1.1" 200 187
# 2021-07-05 20:26:37,632 - telegram.bot - DEBUG - {'id': 1841656712, 'first_name': 'boi', 'is_bot': True, 'username': 'meetBoi_bot'}
# 2021-07-05 20:26:37,634 - telegram.bot - DEBUG - Exiting: get_me
# 2021-07-05 20:26:37,639 - JobQueue - DEBUG - JobQueue thread started
# 2021-07-05 20:26:37,642 - telegram.ext.updater - DEBUG - Bot:1841656712:dispatcher - started
# 2021-07-05 20:26:37,649 - telegram.ext.updater - DEBUG - Bot:1841656712:updater - started
# ...

# %%
#telegram bro stuff
TELEGRAM_TOKEN = '1677969985:AAHdum5fXY-kVHbmTnaGDnRBM7-IqIcOruQ'
TELEGRAM_CHAT_ID = '-587495317'

def bro_message(message):
    try:
        bro_send_this = 'https://api.telegram.org/bot' + TELEGRAM_TOKEN + '/sendMessage?chat_id=' + TELEGRAM_CHAT_ID + '&text=' + message
        response = requests.get(bro_send_this)
    except:
        pass
    



class Meet:
    def __init__(self):
       self.options = webdriver.ChromeOptions()
       self.options.add_argument("--disable-infobars")
       self.options.add_experimental_option("prefs", {"profile.default_content_setting_values.media_stream_camera": 2,"profile.default_content_setting_values.media_stream_mic": 2,"profile.default_content_setting_values.geolocation": 2,"profile.default_content_setting_values.notifications": 2})
       self.bot = webdriver.Chrome(executable_path=r"chromedriver.exe", options=self.options) 
    
    
    def login(self, e_mail, password):
       bot = self.bot
       bot.get("https://stackoverflow.com/users/login") 
       time.sleep(2)
       signinw_field = bot.find_element_by_xpath("/html/body/div[3]/div[2]/div/div[2]/button[1]")
       signinw_field.click()
       time.sleep(2)
       email_field = bot.find_element_by_xpath("/html/body/div[1]/div[1]/div[2]/div/div[2]/div/div/div[2]/div/div[1]/div/form/span/section/div/div/div[1]/div/div[1]/div/div[1]/input")
       email_field.send_keys(e_mail) 
       time.sleep(2)
       next_field = bot.find_element_by_xpath("/html/body/div[1]/div[1]/div[2]/div/div[2]/div/div/div[2]/div/div[2]/div/div[1]/div/div/button/span")
       next_field.click()
       time.sleep(4)
       pass_field = bot.find_element_by_xpath("/html/body/div[1]/div[1]/div[2]/div/div[2]/div/div/div[2]/div/div[1]/div/form/span/section/div/div/div[1]/div[1]/div/div/div/div/div[1]/div/div[1]/input")    
       pass_field.send_keys(password) 
       next1_field = bot.find_element_by_xpath("/html/body/div[1]/div[1]/div[2]/div/div[2]/div/div/div[2]/div/div[2]/div/div[1]/div/div/button/span")
       next1_field.click()
       time.sleep(2)
    
    def join_meet(self, meeting_link):  
       bot=self.bot
       bot.get(meeting_link)
       time.sleep(4)
       dismiss_field = bot.find_element_by_xpath("/html/body/div/div[3]/div/div[2]/div[3]/div/span/span") 
       dismiss_field.click()
       
       time.sleep(4)
       someone = None
       while someone is None:
        try:
            joined = self.bot.find_elements_by_xpath('//div[@class = "Yi3Cfd"]')
            someone = joined[0]
        except:
            #when no one gives a f about lecture
            message = "Koni nahiye bro...de sodun.."
            print(message)
            bro_message(message)
            break
#        for index in range(3):
#          keyboard.send("tab", do_press=True, do_release =True)
#        keyboard.send("enter", do_press=True, do_release =True)  
#        time.sleep(2)     
#        join_field = bot.find_element_by_xpath("/html/body/div[1]/c-wiz/div/div/div[9]/div[3]/div/div/div[4]/div/div/div[2]/div/div[2]/div/div[1]/div[1]/span")
#        join_field.click()
#        for index in range(3):
#           keyboard.send("tab", do_press=True, do_release =True)
#        keyboard.send("enter", do_press=True, do_release =True)  
#        time.sleep(2)    
       
a1= Meet()

a1.login("bhavikakarale2017.comp@mmcoe.edu.in","bhavimmcoe")
a1.join_meet("https://meet.google.com/jeo-dvyr-cfv")

# %%
# def split(word):
#     return [char for char in word]

# numbers = split('0123456789')
# my_string = split('hello 12 hello')

# def common_elements(numbers, my_string):
#     return [element for element in numbers if element in my_string]

# common_elements(numbers, my_string)

# %%
def hasNumbers(inputString):
    return re.search('\s[0-9]+\s', inputString)   

hasNumbers('hello 12 hello')

# %%
# !pip install pyTelegramBotAPI

# %%
import telebot

# %%
TELEGRAM_TOKEN = '1822662313:AAGTZvdcQBWvpTHJLVbyAKeNUaKGJFP_I9o'
CHAT_ID = -587495317

bot = telebot.TeleBot(TELEGRAM_TOKEN)

@bot.message_handler(command=['greet'])
def greet(message):
    bot.reply_to(message, "hey! sup")
    
bot.polling()
